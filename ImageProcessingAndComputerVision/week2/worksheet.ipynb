# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2

# %%
#getting the Cyan color, just to ensure that we can print an RGB image which usees YCN

LoadLena = cv2.imread('lena.png')
LenaImage = cv2.cvtColor(LoadLena, cv2.COLOR_BGR2RGB)
LenaImage.shape

LenaRed = LenaGreen = LenaBlue = LenaCyan = LenaYellow = LenaGreen = LenaImage.shape
LenaRed = LenaImage.copy()
LenaGreen = LenaImage.copy()
LenaBlue = LenaImage.copy()

LenaRed[:,:,[1,2]] = 0
LenaGreen[:,:,[0,2]] = 0
LenaBlue[:,:,[0,1]] = 0

LenaPink = 255 - LenaGreen
LenaYellow = 255 - LenaBlue
LenaCyan = 255 - LenaRed

#plt.imshow(LenaRed)
#plt.show()
#plt.imshow(LenaGreen)
#plt.show()
#plt.imshow(LenaBlue)
#plt.show()
plt.imshow(LenaCyan)
plt.show()
plt.imshow(LenaPink)
plt.show()
plt.imshow(LenaYellow)
plt.show()
final_CMY = LenaCyan + LenaPink + LenaYellow
